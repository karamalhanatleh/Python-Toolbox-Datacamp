# %%
#import
import numpy as np

import pandas as pd

# %%
df= pd.DataFrame()

# %%
x=np.array([1,2,np.nan,4,5,np.nan,np.nan,8,9])

# %%
df['x']=x

# %%
df
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  NaN
# 3  4.0
# 4  5.0
# 5  NaN
# 6  NaN
# 7  8.0
# 8  9.0

# %%
df.fillna(method="bfill")
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  4.0
# 3  4.0
# 4  5.0
# 5  8.0
# 6  8.0
# 7  8.0
# 8  9.0

# %%
df.fillna(method="ffill")
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  2.0
# 3  4.0
# 4  5.0
# 5  5.0
# 6  5.0
# 7  8.0
# 8  9.0

# %%
df.interpolate(method="linear")
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0
# 5  6.0
# 6  7.0
# 7  8.0
# 8  9.0

# %%
df.interpolate(method="quadratic")
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  5.0
# 5  6.0
# 6  7.0
# 7  8.0
# 8  9.0

# %%
df.interpolate(method="nearest")
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  2.0
# 3  4.0
# 4  5.0
# 5  5.0
# 6  8.0
# 7  8.0
# 8  9.0
